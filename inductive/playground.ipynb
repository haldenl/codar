# %%
import json
from vega import VegaLite
from pprint import pprint
import itertools

def load_dataset():
    with open("../sunshine.json", "r") as f:
        target_data = json.load(f)

    with open("../labels.txt", "r") as f:
        labels = [bool(l.strip() == "1") for l in f.readlines()]

    with open("../examples.json", "r") as f:
        vis_specs = json.load(f)
    
    all_rels = {}
    for i,e in enumerate(vis_specs):
        props = infer_facts(e["vl"], [x for x in e["draco"] if not x.startswith("soft")]) 
        rels = infer_relations(props)
        #print(f"{i+1}-------------")
        #VegaLite(e["vl"], target_data).display()
        for r in rels:
            if r not in all_rels:
                all_rels[r] = {"p": 0, "n": 0}
            all_rels[r]["p" if labels[i] == True else "n"] += 1
    
    all_rels = [(key, val["n"], val["p"]) for key, val in all_rels.items()]
    
    pprint(sorted(all_rels, reverse = True, key=lambda x: x[1] - x[2]))
    #return target_data, labels, vis_specs 


def infer_facts(vl_spec, draco_facts):
    props = {}
    props["mark"] = vl_spec["mark"]
    
    facts = {}
    facts["mark"] = f"mark({vl_spec['mark']})"
    facts["encodings"] = {}
    
    # extract data schema type
    field_ty_map = {}
    for x in draco_facts:
        if x.startswith("fieldtype"):
            fieldtype = x[x.index("(")+1:x.index(")")].split(",")
            field = fieldtype[0][1:-1]
            ty = fieldtype[1]
            field_ty_map[field] = ty
    
    props["encoding"] = []
    for i, key in enumerate(vl_spec["encoding"]):
        enc = vl_spec["encoding"][key]
        enc_id = f"e{i}"
        facts["encodings"][enc_id] = []
        facts["encodings"][enc_id].append(f"channel(E,{key})")
        facts["encodings"][enc_id].append(f"enc_ty(E,{enc['type']})")
        facts["encodings"][enc_id].append(f"field_ty(E,{field_ty_map[enc['field']] if 'field' in enc else None})")
        if "aggregate" in enc:
            facts["encodings"][enc_id].append(f"aggregate(E)")
        if "bin" in enc and enc["bin"]:
            facts["encodings"][enc_id].append(f"bin(E)")

    return facts
    
def infer_relations(facts, size=2):
    """Given properties of a spec, infer relations over the spec"""
    rules = []
    for enc_id, enc_facts in facts["encodings"].items():
        for lst in itertools.combinations(enc_facts, size):
            rules.append(f":- {','.join([s for s in lst])}")

    rules.extend([r+f",{facts['mark']}" for r in rules])

    return rules
    
def eliminate_pos(rels, pos_rels):
    return [x for x in rels if x not in pos_rels]

load_dataset()
# Out:
# [(':- aggregate(E),bin(E)', 12, 2),
#  (':- enc_ty(E,quantitative),field_ty(E,number),mark(area)', 8, 0),
#  (':- enc_ty(E,ordinal),field_ty(E,string),mark(area)', 5, 0),
#  (':- aggregate(E),bin(E),mark(area)', 5, 0),
#  (':- channel(E,y),enc_ty(E,quantitative),mark(area)', 5, 0),
#  (':- channel(E,y),field_ty(E,number),mark(area)', 5, 0),
#  (':- channel(E,color),aggregate(E)', 6, 1),
#  (':- channel(E,color),field_ty(E,number),mark(area)', 5, 0),
#  (':- enc_ty(E,ordinal),field_ty(E,number),mark(area)', 5, 0),
#  (':- field_ty(E,number),aggregate(E),mark(area)', 5, 0),
#  (':- field_ty(E,number),bin(E),mark(area)', 5, 0),
#  (':- channel(E,x),field_ty(E,number),mark(area)', 5, 0),
#  (':- channel(E,x),enc_ty(E,ordinal),mark(area)', 4, 0),
#  (':- channel(E,x),bin(E),mark(area)', 4, 0),
#  (':- enc_ty(E,ordinal),aggregate(E),mark(area)', 4, 0),
#  (':- enc_ty(E,ordinal),bin(E),mark(area)', 4, 0),
#  (':- field_ty(E,number),aggregate(E)', 7, 3),
#  (':- field_ty(E,None),bin(E)', 4, 0),
#  (':- enc_ty(E,nominal),field_ty(E,number),mark(area)', 4, 0),
#  (':- channel(E,x),enc_ty(E,quantitative),mark(area)', 4, 0),
#  (':- channel(E,color),enc_ty(E,ordinal)', 5, 2),
#  (':- channel(E,x),aggregate(E)', 4, 1),
#  (':- enc_ty(E,ordinal),aggregate(E)', 7, 4),
#  (':- channel(E,color),enc_ty(E,ordinal),mark(area)', 3, 0),
#  (':- channel(E,x),field_ty(E,string),mark(area)', 3, 0),
#  (':- channel(E,x),aggregate(E),mark(area)', 3, 0),
#  (':- channel(E,color),field_ty(E,number)', 6, 3),
#  (':- channel(E,color),bin(E)', 4, 1),
#  (':- field_ty(E,None),bin(E),mark(point)', 3, 0),
#  (':- aggregate(E),bin(E),mark(point)', 4, 1),
#  (':- channel(E,color),enc_ty(E,nominal),mark(area)', 3, 0),
#  (':- enc_ty(E,ordinal),bin(E)', 6, 4),
#  (':- field_ty(E,number),bin(E)', 7, 5),
#  (':- enc_ty(E,quantitative),bin(E)', 7, 5),
#  (':- channel(E,color),aggregate(E),mark(area)', 2, 0),
#  (':- channel(E,color),bin(E),mark(area)', 2, 0),
#  (':- enc_ty(E,quantitative),bin(E),mark(point)', 3, 1),
#  (':- enc_ty(E,quantitative),bin(E),mark(area)', 2, 0),
#  (':- channel(E,y),field_ty(E,integer),mark(area)', 2, 0),
#  (':- channel(E,detail),enc_ty(E,nominal),mark(point)', 2, 0),
#  (':- channel(E,y),enc_ty(E,nominal),mark(area)', 2, 0),
#  (':- aggregate(E),bin(E),mark(text)', 2, 0),
#  (':- enc_ty(E,quantitative),aggregate(E),mark(area)', 2, 0),
#  (':- channel(E,x),bin(E)', 5, 4),
#  (':- field_ty(E,string),aggregate(E)', 3, 2),
#  (':- channel(E,color),field_ty(E,string),mark(area)', 1, 0),
#  (':- field_ty(E,string),aggregate(E),mark(area)', 1, 0),
#  (':- field_ty(E,string),bin(E),mark(area)', 1, 0),
#  (':- channel(E,detail),enc_ty(E,nominal)', 2, 1),
#  (':- channel(E,text),field_ty(E,integer)', 3, 2),
#  (':- channel(E,text),field_ty(E,integer),mark(text)', 3, 2),
#  (':- channel(E,y),bin(E)', 3, 2),
#  (':- channel(E,color),field_ty(E,None)', 2, 1),
#  (':- channel(E,size),bin(E)', 1, 0),
#  (':- channel(E,y),bin(E),mark(point)', 2, 1),
#  (':- channel(E,color),aggregate(E),mark(point)', 2, 1),
#  (':- channel(E,color),bin(E),mark(point)', 1, 0),
#  (':- channel(E,size),bin(E),mark(point)', 1, 0),
#  (':- enc_ty(E,quantitative),field_ty(E,number),mark(text)', 2, 1),
#  (':- channel(E,color),field_ty(E,number),mark(bar)', 1, 0),
#  (':- channel(E,color),aggregate(E),mark(bar)', 1, 0),
#  (':- channel(E,color),bin(E),mark(bar)', 1, 0),
#  (':- enc_ty(E,ordinal),field_ty(E,number),mark(bar)', 1, 0),
#  (':- enc_ty(E,ordinal),aggregate(E),mark(bar)', 1, 0),
#  (':- enc_ty(E,ordinal),bin(E),mark(bar)', 1, 0),
#  (':- field_ty(E,number),aggregate(E),mark(bar)', 1, 0),
#  (':- field_ty(E,number),bin(E),mark(bar)', 1, 0),
#  (':- aggregate(E),bin(E),mark(bar)', 1, 0),
#  (':- channel(E,y),enc_ty(E,nominal),mark(bar)', 1, 0),
#  (':- channel(E,y),field_ty(E,number),mark(bar)', 1, 0),
#  (':- enc_ty(E,nominal),field_ty(E,number),mark(bar)', 1, 0),
#  (':- channel(E,x),field_ty(E,number),mark(bar)', 1, 0),
#  (':- enc_ty(E,quantitative),field_ty(E,number),mark(bar)', 1, 0),
#  (':- channel(E,y),enc_ty(E,ordinal),mark(area)', 1, 0),
#  (':- channel(E,y),field_ty(E,string),mark(area)', 1, 0),
#  (':- enc_ty(E,quantitative),field_ty(E,integer),mark(area)', 1, 0),
#  (':- channel(E,size),field_ty(E,integer),mark(text)', 1, 0),
#  (':- channel(E,detail),field_ty(E,string)', 1, 0),
#  (':- channel(E,detail),field_ty(E,string),mark(point)', 1, 0),
#  (':- channel(E,detail),field_ty(E,number),mark(point)', 1, 0),
#  (':- channel(E,y),enc_ty(E,quantitative),mark(text)', 1, 0),
#  (':- channel(E,y),aggregate(E),mark(text)', 1, 0),
#  (':- channel(E,y),bin(E),mark(text)', 1, 0),
#  (':- field_ty(E,number),aggregate(E),mark(text)', 1, 0),
#  (':- channel(E,row),enc_ty(E,ordinal),mark(area)', 1, 0),
#  (':- channel(E,row),field_ty(E,number),mark(area)', 1, 0),
#  (':- channel(E,y),aggregate(E),mark(area)', 1, 0),
#  (':- channel(E,column),enc_ty(E,ordinal),mark(area)', 1, 0),
#  (':- channel(E,column),field_ty(E,number),mark(area)', 1, 0),
#  (':- enc_ty(E,nominal),field_ty(E,integer),mark(area)', 1, 0),
#  (':- channel(E,color),field_ty(E,None),mark(text)', 1, 0),
#  (':- channel(E,color),aggregate(E),mark(text)', 1, 0),
#  (':- field_ty(E,None),bin(E),mark(text)', 1, 0),
#  (':- field_ty(E,string),bin(E)', 2, 2),
#  (':- channel(E,detail),field_ty(E,number)', 1, 1),
#  (':- channel(E,color),enc_ty(E,quantitative),mark(text)', 2, 2),
#  (':- channel(E,color),enc_ty(E,ordinal),mark(point)', 1, 1),
#  (':- channel(E,color),field_ty(E,string),mark(point)', 1, 1),
#  (':- channel(E,y),field_ty(E,None)', 1, 1),
#  (':- channel(E,y),aggregate(E)', 4, 4),
#  (':- channel(E,y),field_ty(E,None),mark(point)', 1, 1),
#  (':- enc_ty(E,quantitative),field_ty(E,None),mark(point)', 3, 3),
#  (':- field_ty(E,None),aggregate(E),mark(point)', 3, 3),
#  (':- channel(E,color),field_ty(E,None),mark(point)', 1, 1),
#  (':- channel(E,size),field_ty(E,None),mark(point)', 1, 1),
#  (':- enc_ty(E,ordinal),field_ty(E,integer)', 1, 1),
#  (':- enc_ty(E,ordinal),field_ty(E,integer),mark(text)', 1, 1),
#  (':- channel(E,x),enc_ty(E,quantitative),mark(bar)', 1, 1),
#  (':- channel(E,color),enc_ty(E,ordinal),mark(bar)', 1, 1),
#  (':- field_ty(E,string),aggregate(E),mark(point)', 2, 2),
#  (':- channel(E,size),field_ty(E,integer)', 1, 1),
#  (':- channel(E,text),enc_ty(E,ordinal)', 1, 1),
#  (':- channel(E,size),enc_ty(E,quantitative),mark(text)', 1, 1),
#  (':- channel(E,text),enc_ty(E,ordinal),mark(text)', 1, 1),
#  (':- channel(E,x),field_ty(E,None)', 1, 1),
#  (':- channel(E,x),field_ty(E,None),mark(text)', 1, 1),
#  (':- channel(E,x),aggregate(E),mark(text)', 1, 1),
#  (':- channel(E,x),bin(E),mark(text)', 1, 1),
#  (':- channel(E,x),field_ty(E,number),mark(text)', 1, 1),
#  (':- field_ty(E,number),bin(E),mark(text)', 1, 1),
#  (':- channel(E,column),enc_ty(E,ordinal)', 1, 1),
#  (':- channel(E,x),enc_ty(E,ordinal)', 6, 7),
#  (':- channel(E,row),field_ty(E,number)', 1, 2),
#  (':- channel(E,row),bin(E)', 0, 1),
#  (':- channel(E,detail),enc_ty(E,nominal),mark(tick)', 0, 1),
#  (':- channel(E,detail),field_ty(E,number),mark(tick)', 0, 1),
#  (':- enc_ty(E,nominal),field_ty(E,number),mark(tick)', 0, 1),
#  (':- channel(E,row),field_ty(E,number),mark(tick)', 0, 1),
#  (':- channel(E,row),aggregate(E),mark(tick)', 0, 1),
#  (':- channel(E,row),bin(E),mark(tick)', 0, 1),
#  (':- enc_ty(E,ordinal),aggregate(E),mark(tick)', 0, 1),
#  (':- enc_ty(E,ordinal),bin(E),mark(tick)', 0, 1),
#  (':- field_ty(E,number),aggregate(E),mark(tick)', 0, 1),
#  (':- aggregate(E),bin(E),mark(tick)', 0, 1),
#  (':- channel(E,color),field_ty(E,integer),mark(text)', 1, 2),
#  (':- enc_ty(E,quantitative),bin(E),mark(text)', 2, 3),
#  (':- channel(E,x),enc_ty(E,quantitative),mark(text)', 2, 3),
#  (':- channel(E,column),enc_ty(E,nominal)', 0, 1),
#  (':- channel(E,column),field_ty(E,number)', 1, 2),
#  (':- channel(E,column),enc_ty(E,nominal),mark(point)', 0, 1),
#  (':- channel(E,column),field_ty(E,number),mark(point)', 0, 1),
#  (':- channel(E,row),enc_ty(E,nominal)', 0, 1),
#  (':- channel(E,row),enc_ty(E,nominal),mark(point)', 0, 1),
#  (':- enc_ty(E,quantitative),field_ty(E,None)', 5, 6),
#  (':- enc_ty(E,quantitative),aggregate(E)', 8, 9),
#  (':- field_ty(E,None),aggregate(E)', 5, 6),
#  (':- channel(E,size),field_ty(E,None)', 1, 2),
#  (':- channel(E,y),aggregate(E),mark(point)', 2, 3),
#  (':- enc_ty(E,quantitative),aggregate(E),mark(point)', 3, 4),
#  (':- channel(E,size),aggregate(E),mark(point)', 1, 2),
#  (':- channel(E,y),enc_ty(E,ordinal),mark(text)', 0, 1),
#  (':- channel(E,y),field_ty(E,integer),mark(text)', 0, 1),
#  (':- channel(E,y),enc_ty(E,ordinal),mark(bar)', 0, 1),
#  (':- channel(E,y),field_ty(E,string),mark(bar)', 0, 1),
#  (':- channel(E,color),enc_ty(E,nominal)', 3, 4),
#  (':- channel(E,x),field_ty(E,string),mark(bar)', 0, 1),
#  (':- enc_ty(E,nominal),field_ty(E,integer),mark(bar)', 0, 1),
#  (':- channel(E,shape),field_ty(E,string)', 0, 1),
#  (':- channel(E,shape),field_ty(E,string),mark(point)', 0, 1),
#  (':- channel(E,row),aggregate(E),mark(point)', 0, 1),
#  (':- enc_ty(E,ordinal),aggregate(E),mark(point)', 2, 3),
#  (':- channel(E,y),enc_ty(E,nominal),mark(tick)', 0, 1),
#  (':- channel(E,y),field_ty(E,string),mark(tick)', 0, 1),
#  (':- enc_ty(E,nominal),field_ty(E,string),mark(tick)', 0, 1),
#  (':- field_ty(E,string),bin(E),mark(point)', 1, 2),
#  (':- channel(E,x),enc_ty(E,ordinal),mark(tick)', 0, 1),
#  (':- channel(E,row),field_ty(E,number),mark(point)', 0, 1),
#  (':- field_ty(E,number),aggregate(E),mark(point)', 0, 1),
#  (':- channel(E,size),field_ty(E,integer),mark(point)', 0, 1),
#  (':- field_ty(E,integer),aggregate(E),mark(point)', 0, 1),
#  (':- channel(E,text),field_ty(E,None)', 0, 1),
#  (':- channel(E,text),field_ty(E,None),mark(text)', 0, 1),
#  (':- enc_ty(E,quantitative),field_ty(E,None),mark(text)', 2, 3),
#  (':- enc_ty(E,quantitative),aggregate(E),mark(text)', 3, 4),
#  (':- field_ty(E,None),aggregate(E),mark(text)', 2, 3),
#  (':- channel(E,size),field_ty(E,None),mark(text)', 0, 1),
#  (':- channel(E,size),aggregate(E),mark(text)', 0, 1),
#  (':- field_ty(E,integer),aggregate(E),mark(text)', 0, 1),
#  (':- channel(E,color),bin(E),mark(text)', 0, 1),
#  (':- channel(E,x),enc_ty(E,ordinal),mark(line)', 0, 1),
#  (':- channel(E,x),field_ty(E,number),mark(line)', 0, 1),
#  (':- enc_ty(E,ordinal),field_ty(E,number),mark(line)', 0, 1),
#  (':- channel(E,color),enc_ty(E,quantitative),mark(line)', 0, 1),
#  (':- channel(E,color),field_ty(E,integer),mark(line)', 0, 1),
#  (':- enc_ty(E,quantitative),field_ty(E,integer),mark(line)', 0, 1),
#  (':- channel(E,y),enc_ty(E,quantitative),mark(line)', 0, 1),
#  (':- channel(E,y),field_ty(E,number),mark(line)', 0, 1),
#  (':- channel(E,y),aggregate(E),mark(line)', 0, 1),
#  (':- enc_ty(E,quantitative),field_ty(E,number),mark(line)', 0, 1),
#  (':- enc_ty(E,quantitative),aggregate(E),mark(line)', 0, 1),
#  (':- field_ty(E,number),aggregate(E),mark(line)', 0, 1),
#  (':- channel(E,color),enc_ty(E,nominal),mark(point)', 0, 1),
#  (':- channel(E,y),field_ty(E,number),mark(text)', 1, 2),
#  (':- enc_ty(E,nominal),bin(E)', 0, 1),
#  (':- enc_ty(E,nominal),bin(E),mark(text)', 0, 1),
#  (':- channel(E,text),field_ty(E,string)', 0, 1),
#  (':- channel(E,text),field_ty(E,string),mark(text)', 0, 1),
#  (':- channel(E,color),enc_ty(E,nominal),mark(text)', 0, 1),
#  (':- channel(E,color),field_ty(E,number),mark(text)', 0, 1),
#  (':- channel(E,y),field_ty(E,string),mark(text)', 0, 1),
#  (':- channel(E,x),enc_ty(E,ordinal),mark(text)', 0, 1),
#  (':- channel(E,column),enc_ty(E,ordinal),mark(tick)', 0, 1),
#  (':- channel(E,column),field_ty(E,number),mark(tick)', 0, 1),
#  (':- channel(E,y),bin(E),mark(tick)', 0, 1),
#  (':- enc_ty(E,quantitative),bin(E),mark(tick)', 0, 1),
#  (':- channel(E,size),enc_ty(E,quantitative)', 2, 4),
#  (':- channel(E,size),field_ty(E,number)', 0, 2),
#  (':- channel(E,size),enc_ty(E,quantitative),mark(point)', 1, 3),
#  (':- channel(E,size),field_ty(E,number),mark(point)', 0, 2),
#  (':- channel(E,y),enc_ty(E,ordinal),mark(point)', 1, 3),
#  (':- channel(E,color),field_ty(E,string)', 2, 4),
#  (':- channel(E,y),enc_ty(E,quantitative)', 7, 9),
#  (':- channel(E,row),aggregate(E)', 0, 2),
#  (':- field_ty(E,number),bin(E),mark(tick)', 0, 2),
#  (':- channel(E,text),enc_ty(E,quantitative)', 2, 4),
#  (':- channel(E,text),bin(E)', 0, 2),
#  (':- channel(E,x),enc_ty(E,quantitative)', 7, 9),
#  (':- enc_ty(E,quantitative),field_ty(E,integer),mark(text)', 4, 6),
#  (':- channel(E,text),enc_ty(E,quantitative),mark(text)', 2, 4),
#  (':- channel(E,text),bin(E),mark(text)', 0, 2),
#  (':- channel(E,x),field_ty(E,integer),mark(text)', 0, 2),
#  (':- channel(E,y),enc_ty(E,quantitative),mark(point)', 1, 3),
#  (':- channel(E,row),field_ty(E,string),mark(point)', 0, 2),
#  (':- channel(E,size),aggregate(E)', 1, 3),
#  (':- channel(E,x),enc_ty(E,nominal),mark(text)', 0, 2),
#  (':- channel(E,x),field_ty(E,string),mark(text)', 0, 2),
#  (':- enc_ty(E,ordinal),field_ty(E,string),mark(bar)', 0, 2),
#  (':- channel(E,x),field_ty(E,integer),mark(bar)', 0, 2),
#  (':- channel(E,y),enc_ty(E,quantitative),mark(bar)', 0, 2),
#  (':- channel(E,y),field_ty(E,integer),mark(bar)', 0, 2),
#  (':- channel(E,color),enc_ty(E,nominal),mark(bar)', 0, 2),
#  (':- channel(E,x),enc_ty(E,nominal),mark(bar)', 0, 2),
#  (':- channel(E,row),enc_ty(E,ordinal),mark(point)', 0, 2),
#  (':- channel(E,x),enc_ty(E,quantitative),mark(tick)', 0, 2),
#  (':- channel(E,row),field_ty(E,string),mark(tick)', 0, 2),
#  (':- enc_ty(E,ordinal),field_ty(E,string),mark(tick)', 0, 2),
#  (':- channel(E,x),enc_ty(E,ordinal),mark(point)', 2, 4),
#  (':- enc_ty(E,ordinal),bin(E),mark(point)', 1, 3),
#  (':- channel(E,color),field_ty(E,number),mark(point)', 0, 2),
#  (':- field_ty(E,integer),aggregate(E)', 0, 2),
#  (':- channel(E,text),aggregate(E)', 0, 2),
#  (':- channel(E,text),aggregate(E),mark(text)', 0, 2),
#  (':- channel(E,text),enc_ty(E,nominal)', 0, 2),
#  (':- channel(E,text),enc_ty(E,nominal),mark(text)', 0, 2),
#  (':- field_ty(E,number),bin(E),mark(point)', 0, 2),
#  (':- enc_ty(E,ordinal),field_ty(E,number),mark(text)', 0, 2),
#  (':- enc_ty(E,quantitative),field_ty(E,number)', 11, 14),
#  (':- channel(E,y),enc_ty(E,ordinal)', 2, 5),
#  (':- enc_ty(E,ordinal),field_ty(E,string)', 8, 11),
#  (':- channel(E,y),enc_ty(E,quantitative),mark(tick)', 0, 3),
#  (':- channel(E,y),field_ty(E,number),mark(tick)', 0, 3),
#  (':- channel(E,row),enc_ty(E,ordinal),mark(tick)', 0, 3),
#  (':- enc_ty(E,ordinal),field_ty(E,number),mark(tick)', 0, 3),
#  (':- field_ty(E,integer),bin(E)', 0, 3),
#  (':- field_ty(E,integer),bin(E),mark(text)', 0, 3),
#  (':- channel(E,x),enc_ty(E,quantitative),mark(point)', 0, 3),
#  (':- channel(E,size),field_ty(E,string)', 0, 3),
#  (':- channel(E,size),field_ty(E,string),mark(point)', 0, 3),
#  (':- channel(E,text),field_ty(E,number)', 0, 3),
#  (':- channel(E,text),field_ty(E,number),mark(text)', 0, 3),
#  (':- enc_ty(E,quantitative),field_ty(E,integer),mark(bar)', 0, 3),
#  (':- channel(E,color),field_ty(E,string),mark(bar)', 0, 3),
#  (':- enc_ty(E,nominal),field_ty(E,string),mark(bar)', 0, 3),
#  (':- channel(E,x),field_ty(E,number),mark(tick)', 0, 3),
#  (':- channel(E,shape),field_ty(E,number)', 0, 3),
#  (':- channel(E,x),bin(E),mark(point)', 0, 3),
#  (':- channel(E,shape),field_ty(E,number),mark(point)', 0, 3),
#  (':- channel(E,y),enc_ty(E,nominal),mark(text)', 0, 3),
#  (':- channel(E,y),field_ty(E,string),mark(point)', 1, 5),
#  (':- channel(E,x),field_ty(E,string)', 4, 8),
#  (':- channel(E,x),field_ty(E,string),mark(point)', 1, 5),
#  (':- channel(E,row),enc_ty(E,ordinal)', 1, 5),
#  (':- channel(E,x),field_ty(E,integer)', 0, 4),
#  (':- enc_ty(E,nominal),field_ty(E,integer)', 1, 5),
#  (':- channel(E,y),field_ty(E,integer),mark(point)', 0, 4),
#  (':- enc_ty(E,nominal),field_ty(E,integer),mark(point)', 0, 4),
#  (':- enc_ty(E,ordinal),field_ty(E,string),mark(point)', 3, 7),
#  (':- channel(E,size),enc_ty(E,ordinal)', 0, 4),
#  (':- channel(E,row),field_ty(E,string)', 0, 4),
#  (':- channel(E,size),enc_ty(E,ordinal),mark(point)', 0, 4),
#  (':- enc_ty(E,nominal),field_ty(E,string),mark(text)', 0, 4),
#  (':- channel(E,shape),enc_ty(E,nominal)', 0, 4),
#  (':- channel(E,shape),enc_ty(E,nominal),mark(point)', 0, 4),
#  (':- enc_ty(E,nominal),field_ty(E,number),mark(text)', 0, 4),
#  (':- channel(E,color),field_ty(E,integer),mark(point)', 0, 5),
#  (':- enc_ty(E,quantitative),field_ty(E,number),mark(tick)', 0, 5),
#  (':- channel(E,y),field_ty(E,integer)', 2, 7),
#  (':- channel(E,y),field_ty(E,string)', 2, 8),
#  (':- enc_ty(E,ordinal),field_ty(E,number)', 7, 13),
#  (':- enc_ty(E,ordinal),field_ty(E,number),mark(point)', 1, 7),
#  (':- channel(E,color),enc_ty(E,quantitative),mark(point)', 1, 7),
#  (':- enc_ty(E,quantitative),field_ty(E,integer),mark(point)', 0, 6),
#  (':- enc_ty(E,quantitative),field_ty(E,number),mark(point)', 0, 7),
#  (':- channel(E,y),field_ty(E,number)', 7, 14),
#  (':- channel(E,color),enc_ty(E,quantitative)', 3, 10),
#  (':- channel(E,color),field_ty(E,integer)', 1, 8),
#  (':- channel(E,y),field_ty(E,number),mark(point)', 0, 8),
#  (':- enc_ty(E,nominal),field_ty(E,string),mark(point)', 1, 10),
#  (':- channel(E,x),field_ty(E,number)', 8, 18),
#  (':- channel(E,x),enc_ty(E,nominal),mark(point)', 0, 11),
#  (':- enc_ty(E,quantitative),field_ty(E,integer)', 5, 16),
#  (':- channel(E,y),enc_ty(E,nominal),mark(point)', 0, 12),
#  (':- channel(E,x),field_ty(E,number),mark(point)', 1, 13),
#  (':- channel(E,y),enc_ty(E,nominal)', 3, 16),
#  (':- channel(E,x),enc_ty(E,nominal)', 0, 15),
#  (':- enc_ty(E,nominal),field_ty(E,number)', 6, 21),
#  (':- enc_ty(E,nominal),field_ty(E,number),mark(point)', 1, 16),
#  (':- enc_ty(E,nominal),field_ty(E,string)', 1, 18)]
